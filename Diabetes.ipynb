# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('/Users/shivamsourav/Desktop/di.csv')
df.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/0n/xc9648gx0gsbnhr2j2xllfr00000gn/T/ipykernel_21920/2001914525.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_9b431_row0_col0, #T_9b431_row1_col1, #T_9b431_row2_col2, #T_9b431_row3_col3, #T_9b431_row4_col4, #T_9b431_row5_col5, #T_9b431_row6_col6, #T_9b431_row7_col7, #T_9b431_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9b431_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_9b431_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9b431_row0_col3, #T_9b431_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_9b431_row0_col4, #T_9b431_row0_col5, #T_9b431_row0_col6, #T_9b431_row2_col8, #T_9b431_row3_col0, #T_9b431_row3_col1, #T_9b431_row3_col7, #T_9b431_row6_col2, #T_9b431_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# ...

# %%
y=df['Outcome']
x=df.drop('Outcome',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
d={}

# %%
from sklearn.svm import SVC
machine=SVC()
machine.fit(X_train,y_train)
d['SVM']=machine.score(X_test,y_test)
machine.score(X_test,y_test)
# Out:
# 0.8008658008658008

# %%
log_reg=LogisticRegression()
log_reg.fit(X_train.values,y_train.values)
d['LogisticRegression']=log_reg.score(X_test,y_test)
log_reg.score(X_test,y_test)
# Out:
# /Users/shivamsourav/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/shivamsourav/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/shivamsourav/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# 0.8008658008658008

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
d['DecisionTreeClassifier']=dtc.score(X_test,y_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
d['RandomForestClasssifier']=rfc.score(X_test,y_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
d['KNN']=knn.score(X_test,y_test)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
d['GaussianNB']=gnb.score(X_test,y_test)

# %% [markdown]
# # Acurracy of Differnet Classifiers

# %%
da=pd.DataFrame.from_dict([d])
da
# Out:
#         SVM  LogisticRegression  DecisionTreeClassifier  \
# 0  0.800866            0.800866                0.701299
#
#    RandomForestClasssifier       KNN  GaussianNB
# 0                 0.757576  0.735931    0.779221

# %%
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %% [markdown]
# # We selct Logistic regression as it is mainly used for Binary operations like True or False outcomes

# %%
def predict(x):
    return log_reg.predict([x])[0]

a=float(input('No of pregnancies = '))
b=float(input('Glucose Level = '))
bp=float(input('Blood Pressure = '))
th=float(input('Skin Thickness = '))
ins=float(input('Insulin Level = '))
bmi=float(input('BMI Level = '))
dpf=float(input('Diabetes Pedigreee function = '))
age=float(input('Age = '))

arr=[a,b,bp,th,ins,bmi,dpf,age]

result=predict(arr)
if result==0:
    print('Relax , You do not have Diabetes ! 😄')
else:
    print('Disappointed to say but you have Diabetes 🥲')
# Out:
# No of pregnancies = 5
# Glucose Level = 134
# Blood Pressure = 72
# Skin Thickness = 35
# Insulin Level = 0
# BMI Level = 33.4
# Diabetes Pedigreee function = 0.627
# Age = 50
# Disappointed to say but you have Diabetes 🥲
